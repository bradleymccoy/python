# %% [raw]
# !pip install redis-py

# %% [markdown]
# !pip install gxredis

# %%
import redis 
from gxredis import *

# %%
import sys
import pymongo
from pymongo import MongoClient
import numpy as np
from pandas import Series,DataFrame
import pandas as pd
import json
import csv
from pandas.io.json import json_normalize
from pprint import pprint
from xml.dom.minidom import parse , parseString
import xml.dom.minidom
import xml.etree.ElementTree as ET
import time
import codecs

# %% [markdown]
# to start redis go to redis-latest folder and copy path. use cd redis path in command prompt then call redis-server

# %%
redis.Redis.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9396912dfb90> in <module>()
# ----> 1 redis.Redis.sort()
#
# TypeError: unbound method sort() must be called with Redis instance as first argument (got nothing instead)

# %%
r= redis.StrictRedis(host='localhost',port=6379)

# %%
r.sort('new')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-16-600facb99906> in <module>()
# ----> 1 r.sort('new')
#
# C:\Users\sc97960\AppData\Local\Continuum\Anaconda2\lib\site-packages\redis\client.pyc in sort(self, name, start, num, by, get, desc, alpha, store, groups)
#    1457
#    1458         options = {'groups': len(get) if groups else None}
# -> 1459         return self.execute_command('SORT', *pieces, **options)
#    1460
#    1461     # SCAN COMMANDS
#
# C:\Users\sc97960\AppData\Local\Continuum\Anaconda2\lib\site-packages\redis\client.pyc in execute_command(self, *args, **options)
#     666         try:
#     667             connection.send_command(*args)
# --> 668             return self.parse_response(connection, command_name, **options)
#     669         except (ConnectionError, TimeoutError) as e:
#     670             connection.disconnect()
#
# ...

# %%
r.LSET("Hello")
# Out:
#   File "<ipython-input-5-5e2bcefdd6dd>", line 1
#     r.LSET(lst "Hello")
#                      ^
# SyntaxError: invalid syntax

# %%
r.lpush('new','value2')
# Out:
# 2L

# %%
r.llen('new')
# Out:
# 2

# %%
r.lindex(index = 0, name='new')
# Out:
# 'value2'

# %%
r.lpush('new','val3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-6a2250ddd268> in <module>()
# ----> 1 lpush('new','val3')
#
# NameError: name 'lpush' is not defined

# %%
r.lpush('new','no')
# Out:
# 3L

# %%
dictionary = dict()

# %%
dictionary['keyTest2']='ValueTest2'

# %%
r.lpush('new',dictionary)
# Out:
# 5L

# %%
r.lpush('new',contract)
# Out:
# 6L

# %%
r.lindex('new',0)
# Out:
# "{'keyTest2': 'ValueTest2'}"

# %%
r.scan(match='L*')
# Out:
# (0L, ['L'])

# %%
r.scan()
r.scan(0)
r.sscan(0)
# Out:
# (0L, [])

# %%
r.lpop('new')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f7bdeafe105> in <module>()
# ----> 1 r.lpop('new')
#
# NameError: name 'r' is not defined

# %%
r.lindex('new',0)
# Out:
# "{'keyTest2': 'ValueTest2'}"

# %%
r.ping()
# Out:
# True

# %%
r.shutdown()

# %%
import rejson
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-91-b926333a4c92> in <module>()
# ----> 1 import rejson
#
# ImportError: No module named rejson

# %%
help(redis)
# Out:
# Help on package redis:
#
# NAME
#     redis
#
# FILE
#     c:\users\sc97960\appdata\local\continuum\anaconda2\lib\site-packages\redis\__init__.py
#
# PACKAGE CONTENTS
#     _compat
#     client
#     connection
#     exceptions
#     lock
#     sentinel
#     utils
#
# CLASSES
#     __builtin__.object
#         redis.client.StrictRedis
#             redis.client.Redis
#         redis.connection.Connection
#             redis.connection.SSLConnection
#             redis.connection.UnixDomainSocketConnection
#         redis.connection.ConnectionPool
#             redis.connection.BlockingConnectionPool
#     exceptions.Exception(exceptions.BaseException)
#         redis.exceptions.RedisError
#             redis.exceptions.AuthenticationError
#             redis.exceptions.ConnectionError
#                 redis.exceptions.BusyLoadingError
#             redis.exceptions.DataError
#             redis.exceptions.InvalidResponse
#             redis.exceptions.PubSubError
# ...

# %%
r= redis.StrictRedis()
r.execute_command('JSON.SET','doc','.',json.dumps(x))
reply=json.loads(r.execute_command('JSON.GET','doc'))
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-88-1bfce04ac501> in <module>()
#       1 r= redis.StrictRedis()
# ----> 2 r.execute_command('JSON.SET','doc','.',json.dumps(x))
#       3 reply=json.loads(r.execute_command('JSON.GET','doc'))
#
# C:\Users\sc97960\AppData\Local\Continuum\Anaconda2\lib\site-packages\redis\client.pyc in execute_command(self, *args, **options)
#     666         try:
#     667             connection.send_command(*args)
# --> 668             return self.parse_response(connection, command_name, **options)
#     669         except (ConnectionError, TimeoutError) as e:
#     670             connection.disconnect()
#
# C:\Users\sc97960\AppData\Local\Continuum\Anaconda2\lib\site-packages\redis\client.pyc in parse_response(self, connection, command_name, **options)
#     678     def parse_response(self, connection, command_name, **options):
# ...
